# %%
import pandas as pd

# %%
df=pd.read_csv("netflix_titles_nov_2019.csv")

# %%
df
# Out:
#        show_id                                title  \
# 0     81193313                            Chocolate
# 1     81197050  Guatemala: Heart of the Mayan World
# 2     81213894                      The Zoya Factor
# 3     81082007                            Atlantics
# 4     80213643                      Chip and Potato
# ...        ...                                  ...
# 5832  70141644          Mad Ron's Prevues from Hell
# 5833  70127998                             Splatter
# 5834  70084180              Just Another Love Story
# 5835  70157452                      Dinner for Five
# 5836  70053412                 To and From New York
#
#                         director  \
# 0                            NaN
# 1     Luis Ara, Ignacio Jaunsolo
# 2                Abhishek Sharma
# 3                      Mati Diop
# 4                            NaN
# ...                          ...
# 5832                  Jim Monaco
# 5833                   Joe Dante
# ...

# %%
df.shape
# Out:
# (5837, 12)

# %%
df[50:100]
# Out:
#      show_id                                              title  \
# 50  70091304  Mike Birbiglia: What I Should Have Said Was No...
# 51  81019894                                Nailed It! Holiday!
# 52  81169145                           Narcoworld: Dope Stories
# 53  80244700                                   Nobody's Looking
# 54  81218074                                    Shelby American
# 55  80245262                                   Singapore Social
# 56  80212245                                  The Dragon Prince
# 57  80117560                          Trolls: The Beat Goes On!
# 58  60023606                               K-19: The Widowmaker
# 59  80241539                                             Mortel
# 60  81026188                        The Knight Before Christmas
# 61  70267398                                              Adore
# 62  81152643                                    Bangkok Buddies
# 63  80108983                                        Be Somebody
# ...

# %%
df[['title','rating']]
# Out:
#                                     title rating
# 0                               Chocolate  TV-14
# 1     Guatemala: Heart of the Mayan World   TV-G
# 2                         The Zoya Factor  TV-14
# 3                               Atlantics  TV-14
# 4                         Chip and Potato   TV-Y
# ...                                   ...    ...
# 5832          Mad Ron's Prevues from Hell     NR
# 5833                             Splatter  TV-14
# 5834              Just Another Love Story     NR
# 5835                      Dinner for Five  TV-MA
# 5836                 To and From New York     NR
#
# [5837 rows x 2 columns]

# %%
df.set_index('title')
# Out:
#                                       show_id                    director  \
# title
# Chocolate                            81193313                         NaN
# Guatemala: Heart of the Mayan World  81197050  Luis Ara, Ignacio Jaunsolo
# The Zoya Factor                      81213894             Abhishek Sharma
# Atlantics                            81082007                   Mati Diop
# Chip and Potato                      80213643                         NaN
# ...                                       ...                         ...
# Mad Ron's Prevues from Hell          70141644                  Jim Monaco
# Splatter                             70127998                   Joe Dante
# Just Another Love Story              70084180                Ole Bornedal
# Dinner for Five                      70157452                         NaN
# To and From New York                 70053412        Sorin Dan Mihalcescu
#
# ...

# %%
dfr=df[df['rating']=='TV-14']

# %%
dfr
# Out:
#        show_id             title                director  \
# 0     81193313         Chocolate                     NaN
# 2     81213894   The Zoya Factor         Abhishek Sharma
# 3     81082007         Atlantics               Mati Diop
# 5     81172754      Crazy people            Moses Inwang
# 8     70205672  La Reina del Sur                     NaN
# ...        ...               ...                     ...
# 5774  70153404           Friends                     NaN
# 5790  80005444  Print the Legend  Luis Lopez, Clay Tweel
# 5806  70143811       Gossip Girl                     NaN
# 5808  70157231          The 4400                     NaN
# 5833  70127998          Splatter               Joe Dante
#
#                                                    cast  \
# 0     Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang ...
# 2     Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, ...
# 3     Mama Sane, Amadou Mbow, Ibrahima Traore, Nicol...
# ...

# %% [markdown]
# There are 1593 movies that are of TV-14 rating.

# %%
dfr.to_csv('TV14.csv')

# %%
df[df['type']=='Movie']
# Out:
#        show_id                                title  \
# 1     81197050  Guatemala: Heart of the Mayan World
# 2     81213894                      The Zoya Factor
# 3     81082007                            Atlantics
# 5     81172754                         Crazy people
# 6     81120982                       I Lost My Body
# ...        ...                                  ...
# 5831  70154110                        Even the Rain
# 5832  70141644          Mad Ron's Prevues from Hell
# 5833  70127998                             Splatter
# 5834  70084180              Just Another Love Story
# 5836  70053412                 To and From New York
#
#                         director  \
# 1     Luis Ara, Ignacio Jaunsolo
# 2                Abhishek Sharma
# 3                      Mati Diop
# 5                   Moses Inwang
# 6                  Jérémy Clapin
# ...                          ...
# 5831               Icíar Bollaín
# 5832                  Jim Monaco
# ...

# %% [markdown]
# It shows there are 3939 movies.

# %%
df[df['country']=='India']
# Out:
#        show_id                title  \
# 2     81213894      The Zoya Factor
# 24    81194544  Evvarikee Cheppoddu
# 34    81215481              Pranaam
# 69    81217738            Dorasaani
# 78    81217739            Mallesham
# ...        ...                  ...
# 5407  70153553                Harud
# 5420  80038288               Umrika
# 5478  80115686               Dhanak
# 5485  80115844          John & Jane
# 5545  80108386   X: Past Is Present
#
#                                                director  \
# 2                                       Abhishek Sharma
# 24                                 Basava Shankar Eeday
# 34                                       Sanjiv Jaiswal
# 69                                         KVR Mahendra
# 78                                                Raj R
# ...                                                 ...
# 5407                                       Aamir Bashir
# 5420                                      Prashant Nair
# ...

# %%
dfi=df[df['country']=='India']

# %%
dfi
# Out:
#        show_id                title  \
# 2     81213894      The Zoya Factor
# 24    81194544  Evvarikee Cheppoddu
# 34    81215481              Pranaam
# 69    81217738            Dorasaani
# 78    81217739            Mallesham
# ...        ...                  ...
# 5407  70153553                Harud
# 5420  80038288               Umrika
# 5478  80115686               Dhanak
# 5485  80115844          John & Jane
# 5545  80108386   X: Past Is Present
#
#                                                director  \
# 2                                       Abhishek Sharma
# 24                                 Basava Shankar Eeday
# 34                                       Sanjiv Jaiswal
# 69                                         KVR Mahendra
# 78                                                Raj R
# ...                                                 ...
# 5407                                       Aamir Bashir
# 5420                                      Prashant Nair
# ...

# %%
dfi.to_csv('Indian Movies and  TV Shows.csv')

# %% [markdown]
# Now, dropping the rows with NaN values

# %%
new_df=df.dropna()

# %%
new_df
# Out:
#        show_id                                   title              director  \
# 2     81213894                         The Zoya Factor       Abhishek Sharma
# 3     81082007                               Atlantics             Mati Diop
# 5     81172754                            Crazy people          Moses Inwang
# 6     81120982                          I Lost My Body         Jérémy Clapin
# 7     81227195  Kalushi: The Story of Solomon Mahlangu           Mandla Dube
# ...        ...                                     ...                   ...
# 5831  70154110                           Even the Rain         Icíar Bollaín
# 5832  70141644             Mad Ron's Prevues from Hell            Jim Monaco
# 5833  70127998                                Splatter             Joe Dante
# 5834  70084180                 Just Another Love Story          Ole Bornedal
# 5836  70053412                    To and From New York  Sorin Dan Mihalcescu
#
# ...

# %%
new_df.to_csv("The dataset without any NaN values")

# %%
import numpy as np

# %%
new_df=df.replace({
    'rating':'NR'}, '5 stars' 
)

# %%
new_df
# Out:
#        show_id                                title  \
# 0     81193313                            Chocolate
# 1     81197050  Guatemala: Heart of the Mayan World
# 2     81213894                      The Zoya Factor
# 3     81082007                            Atlantics
# 4     80213643                      Chip and Potato
# ...        ...                                  ...
# 5832  70141644          Mad Ron's Prevues from Hell
# 5833  70127998                             Splatter
# 5834  70084180              Just Another Love Story
# 5835  70157452                      Dinner for Five
# 5836  70053412                 To and From New York
#
#                         director  \
# 0                            NaN
# 1     Luis Ara, Ignacio Jaunsolo
# 2                Abhishek Sharma
# 3                      Mati Diop
# 4                            NaN
# ...                          ...
# 5832                  Jim Monaco
# 5833                   Joe Dante
# ...

# %% [markdown]
# Here the movie and TV shows that had NR rating I gave them 5 stars rating.

# %%
new_df=df.replace({
    'date_added':'[0-9,]',
    'release_year':'[0-9]'},'',regex=True)

# %%
new_df['release_year']
new_df['date_added']
# Out:
# 0       November
# 1       November
# 2       November
# 3       November
# 4              NaN
#            ...
# 5832    November
# 5833    November
# 5834         May
# 5835    February
# 5836     January
# Name: date_added, Length: 5837, dtype: object

# %%
countries=df.groupby('country')
for country,country_df in countries:
    print(country)
    print(country_df)
# Out:
# Argentina
#        show_id                                   title  \
# 98    81105522                       No Time for Shame
# 109   81162089             GO! The Unforgettable Party
# 156   81042948                             Millennials
# 294   81084225  Grego Rossello: Disculpe las molestias
# 323   81105406                 Monzón: A Knockout Blow
# 524   80115297                             El Marginal
# 726   81106517        Apache: The Life of Carlos Tevez
# 869   80994020                                 The Son
# 954   80223153            River, el más grande siempre
# 1071  80220541                       Go! Live Your Way
# 1300  81037237                Heidi, bienvenida a casa
# 1862  81045308                   The Kirlian Frequency
# 1998  81021098                               Just Love
# 2457  80087857                                Creators
# 2997  80993656                                   Mater
# 3092  70266171                    Esperando La Carroza
# ...

# %%
countries.count()
# Out:
#                                                     show_id  title  director  \
# country
# Argentina                                                38     38        26
# Argentina, Brazil, France, Poland, Germany, Den...        1      1         1
# Argentina, Chile                                          1      1         1
# Argentina, Chile, Peru                                    1      1         1
# Argentina, France                                         1      1         1
# ...                                                     ...    ...       ...
# Uruguay, Spain, Mexico                                    1      1         1
# Venezuela                                                 1      1         1
# Venezuela, Colombia                                       1      1         1
# Vietnam                                                   4      4         4
# West Germany                                              1      1         1
#
# ...

# %%
countries.type.count()
# Out:
# country
# Argentina                                              38
# Argentina, Brazil, France, Poland, Germany, Denmark     1
# Argentina, Chile                                        1
# Argentina, Chile, Peru                                  1
# Argentina, France                                       1
#                                                        ..
# Uruguay, Spain, Mexico                                  1
# Venezuela                                               1
# Venezuela, Colombia                                     1
# Vietnam                                                 4
# West Germany                                            1
# Name: type, Length: 527, dtype: int64

# %%
ratings=df.groupby('rating')
for rating, rating_df in ratings:
    print(rating)
    print(rating_df)
# Out:
# G
#        show_id                                              title  \
# 40    60020948                                    Charlotte's Web
# 220     516788                                   Forbidden Planet
# 222     542137                                               Gigi
# 486   60003540                        Rugrats in Paris: The Movie
# 505   18021979                                  The Rugrats Movie
# 571   70118953                                             Océans
# 664   81141689                        Spookley the Square Pumpkin
# 909   70109429                          The Princess and the Frog
# 1008  80005738                                  Room on the Broom
# 2372  70083532                                    The Pixar Story
# 3205  26009364                                             Tarzan
# 3311  80189866                               Pup Star: World Tour
# 3359  80227186                                              Simon
# ...

# %%
a=df.groupby('release_year')

# %%
a

# %%
for year in a:
    print(year)
# Out:
# (1925,        show_id                              title director cast country  \
# 2154  81030762  Pioneers: First Women Filmmakers*      NaN  NaN     NaN
#
#              date_added  release_year rating  duration listed_in  \
# 2154  December 30, 2018          1925  TV-PG  1 Season  TV Shows
#
#                                             description     type
# 2154  This collection restores films from women who ...  TV Show  )
# (1942,        show_id                 title     director                       cast  \
# 4929  60027945        Prelude to War  Frank Capra                        NaN
# 4931  60027942  The Battle of Midway    John Ford  Henry Fonda, Jane Darwell
#
#             country      date_added  release_year rating duration  \
# 4929  United States  March 31, 2017          1942  TV-PG   52 min
# 4931  United States  March 31, 2017          1942   TV-G   18 min
#
#                           listed_in  \
# 4929  Classic Movies, Documentaries
# ...

# %%
indian_movies=df[df['country']=='India']

# %%
indian_movies
# Out:
#        show_id                title  \
# 2     81213894      The Zoya Factor
# 24    81194544  Evvarikee Cheppoddu
# 34    81215481              Pranaam
# 69    81217738            Dorasaani
# 78    81217739            Mallesham
# ...        ...                  ...
# 5407  70153553                Harud
# 5420  80038288               Umrika
# 5478  80115686               Dhanak
# 5485  80115844          John & Jane
# 5545  80108386   X: Past Is Present
#
#                                                director  \
# 2                                       Abhishek Sharma
# 24                                 Basava Shankar Eeday
# 34                                       Sanjiv Jaiswal
# 69                                         KVR Mahendra
# 78                                                Raj R
# ...                                                 ...
# 5407                                       Aamir Bashir
# 5420                                      Prashant Nair
# ...

# %%
release=indian_movies.groupby('release_year')
for r,rdf in release:
    print(rdf['title'])
# Out:
# 4199    Ujala
# Name: title, dtype: object
# 4587    Professor
# Name: title, dtype: object
# 4566    Amrapali
# Name: title, dtype: object
# 4691    Prince
# Name: title, dtype: object
# 4581    Lal Patthar
# 4896          Elaan
# Name: title, dtype: object
# 4375    Khoon Khoon
# Name: title, dtype: object
# 4380    Manoranjan
# Name: title, dtype: object
# 4907    Salaakhen
# Name: title, dtype: object
# 4365    Chadi Jawani Budhe Nu
# Name: title, dtype: object
# 4107    Bandie
# Name: title, dtype: object
# 4367    Ek Jaan Hain Hum
# Name: title, dtype: object
# 3828    Pyar Ke Do Pal
# 4007              Jaal
# Name: title, dtype: object
# 3889    Maza Pati Karodpati
# 4359         Aakhri Adaalat
# Name: title, dtype: object
# 3887    Maine Pyar Kiya
# 4381             Mujrim
# Name: title, dtype: object
# 4735    Chamatkar
# Name: title, dtype: object
# 3636       Khalnayak
# 4667    Aashik Awara
# Name: title, dtype: object
# 3287         Andaz Apna Apna
# ...
