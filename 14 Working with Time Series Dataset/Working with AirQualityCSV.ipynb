# %%
import pandas as pd

# %%
df=pd.read_excel('AirQualityUCI.xlsx','AirQualityUCI')

# %%
df
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0    2004-03-10  18:00:00     2.6      1360.00       150  11.881723
# 1    2004-03-10  19:00:00     2.0      1292.25       112   9.397165
# 2    2004-03-10  20:00:00     2.2      1402.00        88   8.997817
# 3    2004-03-10  21:00:00     2.2      1375.50        80   9.228796
# 4    2004-03-10  22:00:00     1.6      1272.25        51   6.518224
# ...         ...       ...     ...          ...       ...        ...
# 9352 2005-04-04  10:00:00     3.1      1314.25      -200  13.529605
# 9353 2005-04-04  11:00:00     2.4      1162.50      -200  11.355157
# 9354 2005-04-04  12:00:00     2.4      1142.00      -200  12.374538
# 9355 2005-04-04  13:00:00     2.1      1002.50      -200   9.547187
# 9356 2005-04-04  14:00:00     2.2      1070.75      -200  11.932060
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0           1045.50    166.0       1056.25    113.0       1692.00
# ...

# %%
df.to_csv('AirQualityUCIfromcsv.csv',index=False)

# %%
dfc=pd.read_csv('AirQualityUCIfromcsv.csv', parse_dates=[['Date', 'Time']])

# %%
dfc.set_index('Date_Time')
# Out:
#                      CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  PT08.S2(NMHC)  \
# Date_Time
# 2004-03-10 18:00:00     2.6      1360.00       150  11.881723        1045.50
# 2004-03-10 19:00:00     2.0      1292.25       112   9.397165         954.75
# 2004-03-10 20:00:00     2.2      1402.00        88   8.997817         939.25
# 2004-03-10 21:00:00     2.2      1375.50        80   9.228796         948.25
# 2004-03-10 22:00:00     1.6      1272.25        51   6.518224         835.50
# ...                     ...          ...       ...        ...            ...
# 2005-04-04 10:00:00     3.1      1314.25      -200  13.529605        1101.25
# 2005-04-04 11:00:00     2.4      1162.50      -200  11.355157        1027.00
# 2005-04-04 12:00:00     2.4      1142.00      -200  12.374538        1062.50
# 2005-04-04 13:00:00     2.1      1002.50      -200   9.547187         960.50
# 2005-04-04 14:00:00     2.2      1070.75      -200  11.932060        1047.25
#
# ...

# %%
type(dfc['Date_Time'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
dfc.head(5)
# Out:
#             Date_Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0 2004-03-10 18:00:00     2.6      1360.00       150  11.881723
# 1 2004-03-10 19:00:00     2.0      1292.25       112   9.397165
# 2 2004-03-10 20:00:00     2.2      1402.00        88   8.997817
# 3 2004-03-10 21:00:00     2.2      1375.50        80   9.228796
# 4 2004-03-10 22:00:00     1.6      1272.25        51   6.518224
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0        1045.50    166.0       1056.25    113.0       1692.00      1267.50
# 1         954.75    103.0       1173.75     92.0       1558.75       972.25
# 2         939.25    131.0       1140.00    114.0       1554.50      1074.00
# 3         948.25    172.0       1092.00    122.0       1583.75      1203.25
# 4         835.50    131.0       1205.00    116.0       1490.00      1110.00
#
#        T         RH        AH
# 0  13.60  48.875001  0.757754
# 1  13.30  47.700000  0.725487
# ...

# %%
dfc.set_index('Date_Time')
# Out:
#                      CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  PT08.S2(NMHC)  \
# Date_Time
# 2004-03-10 18:00:00     2.6      1360.00       150  11.881723        1045.50
# 2004-03-10 19:00:00     2.0      1292.25       112   9.397165         954.75
# 2004-03-10 20:00:00     2.2      1402.00        88   8.997817         939.25
# 2004-03-10 21:00:00     2.2      1375.50        80   9.228796         948.25
# 2004-03-10 22:00:00     1.6      1272.25        51   6.518224         835.50
# ...                     ...          ...       ...        ...            ...
# 2005-04-04 10:00:00     3.1      1314.25      -200  13.529605        1101.25
# 2005-04-04 11:00:00     2.4      1162.50      -200  11.355157        1027.00
# 2005-04-04 12:00:00     2.4      1142.00      -200  12.374538        1062.50
# 2005-04-04 13:00:00     2.1      1002.50      -200   9.547187         960.50
# 2005-04-04 14:00:00     2.2      1070.75      -200  11.932060        1047.25
#
# ...

# %%
type(dfc['Date_Time'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
dfc.set_index('Date_Time')
# Out:
#                      CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  PT08.S2(NMHC)  \
# Date_Time
# 2004-03-10 18:00:00     2.6      1360.00       150  11.881723        1045.50
# 2004-03-10 19:00:00     2.0      1292.25       112   9.397165         954.75
# 2004-03-10 20:00:00     2.2      1402.00        88   8.997817         939.25
# 2004-03-10 21:00:00     2.2      1375.50        80   9.228796         948.25
# 2004-03-10 22:00:00     1.6      1272.25        51   6.518224         835.50
# ...                     ...          ...       ...        ...            ...
# 2005-04-04 10:00:00     3.1      1314.25      -200  13.529605        1101.25
# 2005-04-04 11:00:00     2.4      1162.50      -200  11.355157        1027.00
# 2005-04-04 12:00:00     2.4      1142.00      -200  12.374538        1062.50
# 2005-04-04 13:00:00     2.1      1002.50      -200   9.547187         960.50
# 2005-04-04 14:00:00     2.2      1070.75      -200  11.932060        1047.25
#
# ...

# %%
dfc = pd.read_csv('AirQualityUCIfromcsv.csv', index_col='Date', parse_dates=True)

# %%
dfc.loc['2005-04-04 00:00:00 ']
# Out:
#                 Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  PT08.S2(NMHC)  \
# Date
# 2005-04-04  00:00:00     0.9      1012.00      -200   3.504006         682.50
# 2005-04-04  01:00:00     0.6       944.25      -200   1.931932         579.00
# 2005-04-04  02:00:00     0.5       911.75      -200   1.489323         543.75
# 2005-04-04  03:00:00     0.4       887.00      -200   1.086365         507.50
# 2005-04-04  04:00:00  -200.0       864.25      -200   0.801504         478.25
# 2005-04-04  05:00:00     0.5       888.25      -200   1.307608         528.00
# 2005-04-04  06:00:00     1.1      1030.50      -200   4.359341         730.25
# 2005-04-04  07:00:00     4.0      1383.50      -200  17.364240        1220.75
# 2005-04-04  08:00:00     5.0      1446.00      -200  22.393233        1361.50
# 2005-04-04  09:00:00     3.9      1296.50      -200  13.552393        1102.00
# 2005-04-04  10:00:00     3.1      1314.25      -200  13.529605        1101.25
# ...

# %%
dfc.loc['2005-04-04'].T.mean()
# Out:
# Series([], dtype: float64)
